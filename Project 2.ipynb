# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import KNeighborsRegressor
from sklearn import linear_model

# %matplotlib inline

# %%
climate_vulnerability = pd.read_csv("vulnerability.csv")

# %%
climate_vulnerability = climate_vulnerability[["ISO3", "Name", "2000", "2010",  "2017"]]

# %%
climate_vulnerability = climate_vulnerability.sort_values('2017')

# %%
climate_vulnerability
# Out:
#     ISO3                              Name      2000      2010      2017
# 166  CHE                       Switzerland  0.276236  0.274659  0.273542
# 128  NOR                            Norway  0.278780  0.261401  0.277732
# 100  LUX                        Luxembourg  0.297664  0.293762  0.285453
# 63   DEU                           Germany  0.297978  0.293893  0.292013
# 8    AUS                         Australia  0.305148  0.303270  0.294721
# 30   CAN                            Canada  0.303172  0.297927  0.295851
# 59   FRA                            France  0.298360  0.297242  0.296253
# 182  GBR                    United Kingdom  0.292465  0.301001  0.298681
# 165  SWE                            Sweden  0.305140  0.306361  0.301165
# 160  ESP                             Spain  0.309119  0.308838  0.307706
# 58   FIN                           Finland  0.318564  0.306985  0.307714
# 45   CZE                    Czech Republic  0.311867  0.310781  0.309574
# ...

# %%
climate_vulnerability = climate_vulnerability.drop([178, 147, 131, 121, 114, 108, 98, 88, 87, 31, 3]) #Drop rows with NaN values
